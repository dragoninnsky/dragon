# %%
# # 2020-11-9
# # 李运辰
#导入库
import librosa
# # 读取音频
# Load a wav file
y, sr = librosa.load('1.wav')
print(y)
#Librosa默认的采样率是22050，如果需要读取原始采样率，需要设定参数sr=None:
print(sr)
y, sr = librosa.load('1.wav',sr=None)
#可见，'beat.wav'的原始采样率为16000。如果需要重采样，只需要将采样率参数sr设定为你需要的值：
print(sr)


y, sr = librosa.load('1.wav',sr=18000)
print(sr)
# Out:
# [0. 0. 0. ... 0. 0. 0.]
# 22050
# 44100
# 18000

# %%
import librosa.display
#绘图
import matplotlib.pyplot as plt
#zhfont1 = matplotlib.font_manager.FontProperties(fname="work/SourceHanSansSC-Bold.otf")#添加中文模块
get_ipython().run_line_magic('matplotlib', 'inline')
plt.figure()
librosa.display.waveplot(y, sr)
plt.title('sample wavform')
plt.show()
